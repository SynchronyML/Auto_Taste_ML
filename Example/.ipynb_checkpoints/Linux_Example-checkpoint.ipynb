# %%
import pandas as pd
import numpy as py
# import warnings
# warnings.filterwarnings("ignore")

# %%
import  auto_ml_c.test as t
# Out:
# 欢迎来到Czy的快乐星球
# 欢迎来到Czy的快乐星球

# %%
import  auto_ml_c.binary_classfication_ws_for_mac as abcwfm
# Out:
# 欢迎来到Czy的快乐星球

# %%
df = pd.read_csv("data_smote_pca_10.csv")
X = df.iloc[:,:-1]
Y = df["label"]
X
# Out:
#              1           2          3          4          5         6  \
# 0    39.210626  -68.990553  36.891540 -27.815414 -30.920674 -1.182138
# 1    31.192749  -51.451800  41.952616 -28.114627 -28.477950  0.531068
# 2    28.862345  -58.730796  59.338951 -42.610398 -39.222084  2.583195
# 3    26.287891  -60.202217  67.858263 -44.211435 -45.438916  0.777141
# 4    93.172594 -103.375669  25.219783 -22.147829 -41.944074 -1.335807
# ..         ...         ...        ...        ...        ...       ...
# 457  42.101203   17.640381  -3.260728 -15.053966   6.722391  6.410839
# 458   4.733575   -8.636892  -0.764952  -1.901150   4.236700  5.859733
# 459 -26.464686    2.653088  -3.405662  -1.576876  -0.652450 -0.405095
# 460 -18.253256    1.198420   2.594235  -0.532642   4.306838  0.871191
# 461 -29.343779    3.382712  -3.940675  -1.294713  -1.937170 -0.537716
#
#             7         8          9         10
# 0    7.706074 -0.084999  -3.574340  -2.393739
# ...

# %% [markdown]
# # 所有函数一个一个来

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.LogisticRegressionCV_mdoel(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 2.311520576477051

# %%
from time import time
A = time()
tmp1,tmp2,tmp3 = t.SGDClassifier_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 0.6573352813720703

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.SVC_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 13.079595565795898

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.DecisionTreeClassifier_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 0.22222471237182617

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.AdaBoostClassifier_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 0.3780534267425537

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.BaggingClassifier_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 0.5520322322845459

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.RandomForestClassifier_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 4.684286594390869

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.GradientBoostingClassifier_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 3.8882031440734863

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.KNeighborsClassifier_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 1.1185719966888428

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.BernoulliNB_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 0.037409305572509766

# %%
from time import time
A = time()
tmp1,tmp2,tmp3  = t.GaussianNB_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# 0.01996302604675293

# %% [markdown]
# ## 计算得到ROC图

# %%
from time import time
A = time()
a = t.binary_ROC(X,Y,5,"ROC1111","accuracy")
B= time()
print(B-A)
a
# Out:
# {'class_weight': 'none', 'solver': 'sag'} 0.5693548387096774 LogisticRegressionCV(class_weight='none', max_iter=10000, n_jobs=-1,
#                      random_state=0, solver='sag')
# {'average': False, 'early_stopping': False, 'fit_intercept': True, 'loss': 'log', 'penalty': 'elasticnet', 'warm_start': True} 0.5864656381486676 SGDClassifier(class_weight='balanced', loss='log', max_iter=10000, n_jobs=-1,
#               penalty='elasticnet', random_state=0, warm_start=True)
# {'solver': 'svd', 'store_covariance': True} 0.567180925666199 LinearDiscriminantAnalysis(store_covariance=True)
# {'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True} 0.6968910705937355 SVC(class_weight='balanced', gamma='auto', probability=True, random_state=0)
# {'criterion': 'entropy', 'max_features': 'auto', 'splitter': 'best'} 0.7703833567087424 DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_features='auto', random_state=0)
# ...

# %% [markdown]
# # 计算得到四大评价指标

# %%
from time import time
A = time()
Auc_data, Acc_data, Recall_data, Precision_data = t.auto_model(X,Y,5,"accuracy")
B= time()
print(B-A)
# Out:
# {'class_weight': 'none', 'solver': 'sag'} 0.5693548387096774 LogisticRegressionCV(class_weight='none', max_iter=10000, n_jobs=-1,
#                      random_state=0, solver='sag')
# {'average': False, 'early_stopping': False, 'fit_intercept': True, 'loss': 'log', 'penalty': 'elasticnet', 'warm_start': True} 0.5864656381486676 SGDClassifier(class_weight='balanced', loss='log', max_iter=10000, n_jobs=-1,
#               penalty='elasticnet', random_state=0, warm_start=True)
# {'solver': 'svd', 'store_covariance': True} 0.567180925666199 LinearDiscriminantAnalysis(store_covariance=True)
# {'gamma': 'auto', 'kernel': 'rbf', 'shrinking': True} 0.6968910705937355 SVC(class_weight='balanced', gamma='auto', probability=True, random_state=0)
# {'criterion': 'entropy', 'max_features': 'auto', 'splitter': 'best'} 0.7703833567087424 DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_features='auto', random_state=0)
# ...

# %%
from time import time
A = time()
a = t.estimator_violion(Auc_data,Acc_data,"accuracy")
B= time()
print(B-A)
a
# Out:
# 1.1560215950012207
